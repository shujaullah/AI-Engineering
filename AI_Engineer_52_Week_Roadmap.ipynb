# %%
# Week #1
### August 17, 2026

# %%
print("Hello Python!")

# %%
name = "Shuja"
age = 30
height = 5.9
is_developer = True

print(name)
print(age)
print(height)
print(is_developer)
# Out:
# Shuja
# 30
# 5.9
# True

# %%
a = 10
b = 3

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
age = 30;

if(age >= 18):
    print("You are an adult.")
# Out:
# You are an adult.

# %%
number = int(input("Enter a number: "))
if(number % 2 == 0):
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# The number is even.

# %%
a = input("Enter first number: ")
b = input("Enter second number: ")
c = input("Enter third number: ")

largest = max(a, b, c)

print(f"The largest number is {largest}")
# Out:
# The largest number is 9

# %%
#Exercise 3 Creating a simple calculator 

a = float(input("Enter first number: "))
operation = input("Enter operation (+, -, *, /): ")
b = float(input("Enter second number: "))

if operation == "+":
    result = a + b
elif operation == "-":
    result = a - b
elif operation == "*":
    result = a * b
elif operation == "/":
    if b != 0:
        result = a / b
    else:
        result = "Error: Division by zero"
else:
    result = "Error: Invalid operation" 

print(f"The result is: {result}")
# Out:
# The result is: 715.0

# %%
# Week #2

# %%
# . Lists — think C++ vector

numbers = [10, 20, 30, 40, 50]

print(numbers[0])  # Accessing the first element
print(numbers[-1])  # Accessing the third element

numbers.append(60)  # Adding an element to the end of the list
print(numbers)

numbers.remove(30)  # Removing an element from the list
print(numbers)
# Out:
# 10
# 50
# [10, 20, 30, 40, 50, 60]
# [10, 20, 40, 50, 60]
