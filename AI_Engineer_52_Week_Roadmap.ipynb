# %%
# Week #1
### August 17, 2026

# %%
print("Hello Python!")
# Out:
# Hello Python!

# %%
name = "Shuja"
age = 30
height = 5.9
is_developer = True

print(name)
print(age)
print(height)
print(is_developer)
# Out:
# Shuja
# 30
# 5.9
# True

# %%
first_name ="Shujaullah"
last_name = "Ahsan"

full_name = first_name + " "+last_name
print(full_name)

print(f"My name is {full_name}")
# Out:
# Shujaullah Ahsan
# My name is Shujaullah Ahsan
